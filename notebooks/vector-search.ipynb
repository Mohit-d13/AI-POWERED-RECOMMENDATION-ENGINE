# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_chroma import Chroma

# %% [markdown]
# ### TextLoader  - Convert the raw text data of movies to a format langchain can work with.
# ### CharacterTextSplitter - Converting the whole document of movies's overview to meanningful chunks of data.
# ### HuggingFaceEmbeddings - Convert the chunks of data into document embeddings and do api call to HuggingFaceEmbedding model.
# ### Chroma - To store the embedded document into vector database.

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import pandas as pd

movies = pd.read_csv("data/movies_cleaned.csv")

# %%
movies
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year  Runtime  \
# 0    The Shawshank Redemption          1994  142 min
# 1               The Godfather          1972  175 min
# 2             The Dark Knight          2008  152 min
# 3      The Godfather: Part II          1974  202 min
# 4                12 Angry Men          1957   96 min
# ..                        ...           ...      ...
# 995    Breakfast at Tiffany's          1961  115 min
# 996                     Giant          1956  201 min
# 997     From Here to Eternity          1953  118 min
# 998                  Lifeboat          1944   97 min
# 999              The 39 Steps          1935   86 min
#
#                         Genre  IMDB_Rating  \
# 0                       Drama          9.3
# 1                Crime, Drama          9.2
# 2        Action, Crime, Drama          9.0
# 3                Crime, Drama          9.0
# 4                Crime, Drama          9.0
# ..                        ...          ...
# 995    Comedy, Drama, Romance          7.6
# 996            Drama, Western          7.6
# 997       Drama, Romance, War          7.6
# 998                Drama, War          7.6
# 999  Crime, Mystery, Thriller          7.6
#
#                                               Overview              Director  \
# 0    Two imprisoned men bond over a number of years...        Frank Darabont
# 1    An organized crime dynasty's aging patriarch t...  Francis Ford Coppola
# 2    When the menace known as the Joker wreaks havo...     Christopher Nolan
# 3    The early life and career of Vito Corleone in ...  Francis Ford Coppola
# 4    A jury holdout attempts to prevent a miscarria...          Sidney Lumet
# ..                                                 ...                   ...
# 995  A young New York socialite becomes interested ...         Blake Edwards
# 996  Sprawling epic covering the life of a Texas ca...        George Stevens
# 997  In Hawaii in 1941, a private is cruelly punish...        Fred Zinnemann
# 998  Several survivors of a torpedoed merchant ship...      Alfred Hitchcock
# 999  A man in London tries to help a counter-espion...      Alfred Hitchcock
#
#                  Star1              Star2           Star3           Star4  \
# 0          Tim Robbins     Morgan Freeman      Bob Gunton  William Sadler
# 1        Marlon Brando          Al Pacino      James Caan    Diane Keaton
# 2       Christian Bale       Heath Ledger   Aaron Eckhart   Michael Caine
# 3            Al Pacino     Robert De Niro   Robert Duvall    Diane Keaton
# 4          Henry Fonda        Lee J. Cobb   Martin Balsam    John Fiedler
# ..                 ...                ...             ...             ...
# 995     Audrey Hepburn     George Peppard   Patricia Neal     Buddy Ebsen
# 996   Elizabeth Taylor        Rock Hudson      James Dean   Carroll Baker
# 997     Burt Lancaster   Montgomery Clift    Deborah Kerr      Donna Reed
# 998  Tallulah Bankhead        John Hodiak   Walter Slezak  William Bendix
# 999       Robert Donat  Madeleine Carroll  Lucie Mannheim  Godfrey Tearle
#
#      No_of_Votes  Unique_id  \
# 0        2343110          1
# 1        1620367          2
# 2        2303232          3
# 3        1129952          4
# 4         689845          5
# ..           ...        ...
# 995       166544        996
# 996        34075        997
# 997        43374        998
# 998        26471        999
# 999        51853       1000
#
#                                     tagged_description  \
# 0    1 Two imprisoned men bond over a number of yea...
# 1    2 An organized crime dynasty's aging patriarch...
# 2    3 When the menace known as the Joker wreaks ha...
# 3    4 The early life and career of Vito Corleone i...
# 4    5 A jury holdout attempts to prevent a miscarr...
# ..                                                 ...
# 995  996 A young New York socialite becomes interes...
# 996  997 Sprawling epic covering the life of a Texa...
# 997  998 In Hawaii in 1941, a private is cruelly pu...
# 998  999 Several survivors of a torpedoed merchant ...
# 999  1000 A man in London tries to help a counter-e...
#
#                                     Tagged_description
# 0    1 Two imprisoned men bond over a number of yea...
# 1    2 An organized crime dynasty's aging patriarch...
# 2    3 When the menace known as the Joker wreaks ha...
# 3    4 The early life and career of Vito Corleone i...
# 4    5 A jury holdout attempts to prevent a miscarr...
# ..                                                 ...
# 995  996 A young New York socialite becomes interes...
# 996  997 Sprawling epic covering the life of a Texa...
# 997  998 In Hawaii in 1941, a private is cruelly pu...
# 998  999 Several survivors of a torpedoed merchant ...
# 999  1000 A man in London tries to help a counter-e...
#
# [1000 rows x 16 columns]

# %%
# Seperate tagged_description into textfile
# Create document file with raw chunks of document data

movies['tagged_description'].to_csv('tagged_description.txt',
                                    sep='\n',
                                    index=False,
                                    header=False)

# %%
raw_documents = TextLoader('tagged_description.txt').load()
text_splitter = CharacterTextSplitter(chunk_size=0, chunk_overlap=0, separator="\n")
documents = text_splitter.split_documents(raw_documents)
# Out:
# Created a chunk of size 120, which is longer than the specified 0
# Created a chunk of size 112, which is longer than the specified 0
# Created a chunk of size 191, which is longer than the specified 0
# Created a chunk of size 166, which is longer than the specified 0
# Created a chunk of size 115, which is longer than the specified 0
# Created a chunk of size 148, which is longer than the specified 0
# Created a chunk of size 145, which is longer than the specified 0
# Created a chunk of size 180, which is longer than the specified 0
# Created a chunk of size 154, which is longer than the specified 0
# Created a chunk of size 136, which is longer than the specified 0
# Created a chunk of size 155, which is longer than the specified 0
# Created a chunk of size 238, which is longer than the specified 0
# Created a chunk of size 141, which is longer than the specified 0
# Created a chunk of size 181, which is longer than the specified 0
# Created a chunk of size 191, which is longer than the specified 0
# Created a chunk of size 194, which is longer than the specified 0
# Created a chunk of size 231, which is longer than the specified 0
# Created a chunk of size 151, which is longer than the specified 0
# Created a chunk of size 211, which is longer than the specified 0
# Created a chunk of size 142, which is longer than the specified 0
# Created a chunk of size 184, which is longer than the specified 0
# Created a chunk of size 102, which is longer than the specified 0
# Created a chunk of size 114, which is longer than the specified 0
# Created a chunk of size 169, which is longer than the specified 0
# Created a chunk of size 151, which is longer than the specified 0
# Created a chunk of size 150, which is longer than the specified 0
# Created a chunk of size 197, which is longer than the specified 0
# Created a chunk of size 110, which is longer than the specified 0
# Created a chunk of size 166, which is longer than the specified 0
# Created a chunk of size 239, which is longer than the specified 0
# Created a chunk of size 225, which is longer than the specified 0
# Created a chunk of size 107, which is longer than the specified 0
# Created a chunk of size 147, which is longer than the specified 0
# Created a chunk of size 234, which is longer than the specified 0
# Created a chunk of size 190, which is longer than the specified 0
# Created a chunk of size 134, which is longer than the specified 0
# Created a chunk of size 159, which is longer than the specified 0
# Created a chunk of size 126, which is longer than the specified 0
# Created a chunk of size 102, which is longer than the specified 0
# Created a chunk of size 132, which is longer than the specified 0
# Created a chunk of size 115, which is longer than the specified 0
# Created a chunk of size 165, which is longer than the specified 0
# Created a chunk of size 214, which is longer than the specified 0
# Created a chunk of size 109, which is longer than the specified 0
# Created a chunk of size 155, which is longer than the specified 0
# Created a chunk of size 170, which is longer than the specified 0
# Created a chunk of size 86, which is longer than the specified 0
# Created a chunk of size 192, which is longer than the specified 0
# Created a chunk of size 161, which is longer than the specified 0
# Created a chunk of size 171, which is longer than the specified 0
# Created a chunk of size 164, which is longer than the specified 0
# Created a chunk of size 100, which is longer than the specified 0
# Created a chunk of size 167, which is longer than the specified 0
# Created a chunk of size 106, which is longer than the specified 0
# Created a chunk of size 231, which is longer than the specified 0
# Created a chunk of size 199, which is longer than the specified 0
# Created a chunk of size 134, which is longer than the specified 0
# Created a chunk of size 155, which is longer than the specified 0
# Created a chunk of size 170, which is longer than the specified 0
# Created a chunk of size 231, which is longer than the specified 0
# Created a chunk of size 179, which is longer than the specified 0
# Created a chunk of size 166, which is longer than the specified 0
# Created a chunk of size 129, which is longer than the specified 0
# Created a chunk of size 186, which is longer than the specified 0
# Created a chunk of size 227, which is longer than the specified 0
# Created a chunk of size 182, which is longer than the specified 0
# Created a chunk of size 146, which is longer than the specified 0
# Created a chunk of size 166, which is longer than the specified 0
# Created a chunk of size 137, which is longer than the specified 0
# Created a chunk of size 80, which is longer than the specified 0
# Created a chunk of size 209, which is longer than the specified 0
# Created a chunk of size 186, which is longer than the specified 0
# Created a chunk of size 177, which is longer than the specified 0
# Created a chunk of size 191, which is longer than the specified 0
# Created a chunk of size 131, which is longer than the specified 0
# Created a chunk of size 199, which is longer than the specified 0
# Created a chunk of size 133, which is longer than the specified 0
# Created a chunk of size 122, which is longer than the specified 0
# Created a chunk of size 133, which is longer than the specified 0
# Created a chunk of size 105, which is longer than the specified 0
# Created a chunk of size 137, which is longer than the specified 0
# Created a chunk of size 139, which is longer than the specified 0
# Created a chunk of size 114, which is longer than the specified 0
# Created a chunk of size 129, which is longer than the specified 0
# Created a chunk of size 216, which is longer than the specified 0
# Created a chunk of size 161, which is longer than the specified 0
# Created a chunk of size 140, which is longer than the specified 0
# Created a chunk of size 113, which is longer than the specified 0
# Created a chunk of size 242, which is longer than the specified 0
# Created a chunk of size 207, which is longer than the specified 0
# Created a chunk of size 108, which is longer than the specified 0
# Created a chunk of size 216, which is longer than the specified 0
# Created a chunk of size 96, which is longer than the specified 0
# Created a chunk of size 179, which is longer than the specified 0
# Created a chunk of size 124, which is longer than the specified 0
# Created a chunk of size 153, which is longer than the specified 0
# Created a chunk of size 180, which is longer than the specified 0
# Created a chunk of size 101, which is longer than the specified 0
# Created a chunk of size 121, which is longer than the specified 0
# Created a chunk of size 132, which is longer than the specified 0
# Created a chunk of size 165, which is longer than the specified 0
# Created a chunk of size 123, which is longer than the specified 0
# Created a chunk of size 139, which is longer than the specified 0
# Created a chunk of size 133, which is longer than the specified 0
# Created a chunk of size 179, which is longer than the specified 0
# Created a chunk of size 156, which is longer than the specified 0
# Created a chunk of size 215, which is longer than the specified 0
# Created a chunk of size 197, which is longer than the specified 0
# Created a chunk of size 95, which is longer than the specified 0
# Created a chunk of size 240, which is longer than the specified 0
# Created a chunk of size 86, which is longer than the specified 0
# Created a chunk of size 242, which is longer than the specified 0
# Created a chunk of size 54, which is longer than the specified 0
# Created a chunk of size 135, which is longer than the specified 0
# Created a chunk of size 179, which is longer than the specified 0
# Created a chunk of size 87, which is longer than the specified 0
# Created a chunk of size 171, which is longer than the specified 0
# Created a chunk of size 144, which is longer than the specified 0
# Created a chunk of size 130, which is longer than the specified 0
# Created a chunk of size 129, which is longer than the specified 0
# Created a chunk of size 83, which is longer than the specified 0
# Created a chunk of size 95, which is longer than the specified 0
# Created a chunk of size 98, which is longer than the specified 0
# Created a chunk of size 173, which is longer than the specified 0
# Created a chunk of size 142, which is longer than the specified 0
# Created a chunk of size 111, which is longer than the specified 0
# Created a chunk of size 231, which is longer than the specified 0
# Created a chunk of size 89, which is longer than the specified 0
# Created a chunk of size 172, which is longer than the specified 0
# Created a chunk of size 134, which is longer than the specified 0
# Created a chunk of size 129, which is longer than the specified 0
# Created a chunk of size 158, which is longer than the specified 0
# Created a chunk of size 124, which is longer than the specified 0
# Created a chunk of size 123, which is longer than the specified 0
# Created a chunk of size 176, which is longer than the specified 0
# Created a chunk of size 233, which is longer than the specified 0
# Created a chunk of size 140, which is longer than the specified 0
# Created a chunk of size 106, which is longer than the specified 0
# Created a chunk of size 236, which is longer than the specified 0
# Created a chunk of size 107, which is longer than the specified 0
# Created a chunk of size 149, which is longer than the specified 0
# Created a chunk of size 98, which is longer than the specified 0
# Created a chunk of size 181, which is longer than the specified 0
# Created a chunk of size 210, which is longer than the specified 0
# Created a chunk of size 235, which is longer than the specified 0
# Created a chunk of size 127, which is longer than the specified 0
# Created a chunk of size 134, which is longer than the specified 0
# Created a chunk of size 175, which is longer than the specified 0
# Created a chunk of size 150, which is longer than the specified 0
# Created a chunk of size 137, which is longer than the specified 0
# Created a chunk of size 146, which is longer than the specified 0
# Created a chunk of size 213, which is longer than the specified 0
# Created a chunk of size 149, which is longer than the specified 0
# Created a chunk of size 201, which is longer than the specified 0
# Created a chunk of size 130, which is longer than the specified 0
# Created a chunk of size 109, which is longer than the specified 0
# Created a chunk of size 142, which is longer than the specified 0
# Created a chunk of size 136, which is longer than the specified 0
# Created a chunk of size 224, which is longer than the specified 0
# Created a chunk of size 139, which is longer than the specified 0
# Created a chunk of size 142, which is longer than the specified 0
# Created a chunk of size 243, which is longer than the specified 0
# Created a chunk of size 175, which is longer than the specified 0
# Created a chunk of size 96, which is longer than the specified 0
# Created a chunk of size 133, which is longer than the specified 0
# Created a chunk of size 229, which is longer than the specified 0
# Created a chunk of size 118, which is longer than the specified 0
# Created a chunk of size 165, which is longer than the specified 0
# Created a chunk of size 233, which is longer than the specified 0
# Created a chunk of size 239, which is longer than the specified 0
# Created a chunk of size 141, which is longer than the specified 0
# Created a chunk of size 159, which is longer than the specified 0
# Created a chunk of size 217, which is longer than the specified 0
# Created a chunk of size 131, which is longer than the specified 0
# Created a chunk of size 94, which is longer than the specified 0
# Created a chunk of size 110, which is longer than the specified 0
# Created a chunk of size 136, which is longer than the specified 0
# Created a chunk of size 151, which is longer than the specified 0
# Created a chunk of size 150, which is longer than the specified 0
# Created a chunk of size 118, which is longer than the specified 0
# Created a chunk of size 147, which is longer than the specified 0
# Created a chunk of size 126, which is longer than the specified 0
# Created a chunk of size 90, which is longer than the specified 0
# Created a chunk of size 143, which is longer than the specified 0
# Created a chunk of size 116, which is longer than the specified 0
# Created a chunk of size 134, which is longer than the specified 0
# Created a chunk of size 82, which is longer than the specified 0
# Created a chunk of size 91, which is longer than the specified 0
# Created a chunk of size 99, which is longer than the specified 0
# Created a chunk of size 158, which is longer than the specified 0
# Created a chunk of size 147, which is longer than the specified 0
# Created a chunk of size 131, which is longer than the specified 0
# Created a chunk of size 134, which is longer than the specified 0
# Created a chunk of size 78, which is longer than the specified 0
# Created a chunk of size 165, which is longer than the specified 0
# Created a chunk of size 149, which is longer than the specified 0
# Created a chunk of size 116, which is longer than the specified 0
# Created a chunk of size 162, which is longer than the specified 0
# Created a chunk of size 147, which is longer than the specified 0
# Created a chunk of size 114, which is longer than the specified 0
# Created a chunk of size 139, which is longer than the specified 0
# Created a chunk of size 147, which is longer than the specified 0
# Created a chunk of size 200, which is longer than the specified 0
# Created a chunk of size 173, which is longer than the specified 0
# Created a chunk of size 98, which is longer than the specified 0
# Created a chunk of size 146, which is longer than the specified 0
# Created a chunk of size 130, which is longer than the specified 0
# Created a chunk of size 202, which is longer than the specified 0
# Created a chunk of size 80, which is longer than the specified 0
# Created a chunk of size 181, which is longer than the specified 0
# Created a chunk of size 173, which is longer than the specified 0
# Created a chunk of size 241, which is longer than the specified 0
# Created a chunk of size 217, which is longer than the specified 0
# Created a chunk of size 202, which is longer than the specified 0
# Created a chunk of size 123, which is longer than the specified 0
# Created a chunk of size 128, which is longer than the specified 0
# Created a chunk of size 85, which is longer than the specified 0
# Created a chunk of size 221, which is longer than the specified 0
# Created a chunk of size 193, which is longer than the specified 0
# Created a chunk of size 157, which is longer than the specified 0
# Created a chunk of size 142, which is longer than the specified 0
# Created a chunk of size 109, which is longer than the specified 0
# Created a chunk of size 156, which is longer than the specified 0
# Created a chunk of size 198, which is longer than the specified 0
# Created a chunk of size 199, which is longer than the specified 0
# Created a chunk of size 177, which is longer than the specified 0
# Created a chunk of size 154, which is longer than the specified 0
# Created a chunk of size 75, which is longer than the specified 0
# Created a chunk of size 75, which is longer than the specified 0
# Created a chunk of size 198, which is longer than the specified 0
# Created a chunk of size 172, which is longer than the specified 0
# Created a chunk of size 302, which is longer than the specified 0
# Created a chunk of size 144, which is longer than the specified 0
# Created a chunk of size 108, which is longer than the specified 0
# Created a chunk of size 85, which is longer than the specified 0
# Created a chunk of size 143, which is longer than the specified 0
# Created a chunk of size 156, which is longer than the specified 0
# Created a chunk of size 120, which is longer than the specified 0
# Created a chunk of size 75, which is longer than the specified 0
# Created a chunk of size 155, which is longer than the specified 0
# Created a chunk of size 195, which is longer than the specified 0
# Created a chunk of size 120, which is longer than the specified 0
# Created a chunk of size 135, which is longer than the specified 0
# Created a chunk of size 186, which is longer than the specified 0
# Created a chunk of size 157, which is longer than the specified 0
# Created a chunk of size 219, which is longer than the specified 0
# Created a chunk of size 79, which is longer than the specified 0
# Created a chunk of size 131, which is longer than the specified 0
# Created a chunk of size 92, which is longer than the specified 0
# Created a chunk of size 111, which is longer than the specified 0
# Created a chunk of size 81, which is longer than the specified 0
# Created a chunk of size 241, which is longer than the specified 0
# Created a chunk of size 163, which is longer than the specified 0
# Created a chunk of size 201, which is longer than the specified 0
# Created a chunk of size 145, which is longer than the specified 0
# Created a chunk of size 155, which is longer than the specified 0
# Created a chunk of size 124, which is longer than the specified 0
# Created a chunk of size 96, which is longer than the specified 0
# Created a chunk of size 152, which is longer than the specified 0
# Created a chunk of size 184, which is longer than the specified 0
# Created a chunk of size 75, which is longer than the specified 0
# Created a chunk of size 188, which is longer than the specified 0
# Created a chunk of size 183, which is longer than the specified 0
# Created a chunk of size 159, which is longer than the specified 0
# Created a chunk of size 188, which is longer than the specified 0
# Created a chunk of size 140, which is longer than the specified 0
# Created a chunk of size 121, which is longer than the specified 0
# Created a chunk of size 132, which is longer than the specified 0
# Created a chunk of size 223, which is longer than the specified 0
# Created a chunk of size 171, which is longer than the specified 0
# Created a chunk of size 147, which is longer than the specified 0
# Created a chunk of size 113, which is longer than the specified 0
# Created a chunk of size 124, which is longer than the specified 0
# Created a chunk of size 133, which is longer than the specified 0
# Created a chunk of size 103, which is longer than the specified 0
# Created a chunk of size 137, which is longer than the specified 0
# Created a chunk of size 223, which is longer than the specified 0
# Created a chunk of size 139, which is longer than the specified 0
# Created a chunk of size 154, which is longer than the specified 0
# Created a chunk of size 155, which is longer than the specified 0
# Created a chunk of size 135, which is longer than the specified 0
# Created a chunk of size 127, which is longer than the specified 0
# Created a chunk of size 173, which is longer than the specified 0
# Created a chunk of size 120, which is longer than the specified 0
# Created a chunk of size 161, which is longer than the specified 0
# Created a chunk of size 163, which is longer than the specified 0
# Created a chunk of size 125, which is longer than the specified 0
# Created a chunk of size 136, which is longer than the specified 0
# Created a chunk of size 97, which is longer than the specified 0
# Created a chunk of size 98, which is longer than the specified 0
# Created a chunk of size 100, which is longer than the specified 0
# Created a chunk of size 120, which is longer than the specified 0
# Created a chunk of size 78, which is longer than the specified 0
# Created a chunk of size 91, which is longer than the specified 0
# Created a chunk of size 142, which is longer than the specified 0
# Created a chunk of size 108, which is longer than the specified 0
# Created a chunk of size 181, which is longer than the specified 0
# Created a chunk of size 201, which is longer than the specified 0
# Created a chunk of size 149, which is longer than the specified 0
# Created a chunk of size 75, which is longer than the specified 0
# Created a chunk of size 129, which is longer than the specified 0
# Created a chunk of size 104, which is longer than the specified 0
# Created a chunk of size 101, which is longer than the specified 0
# Created a chunk of size 137, which is longer than the specified 0
# Created a chunk of size 166, which is longer than the specified 0
# Created a chunk of size 94, which is longer than the specified 0
# Created a chunk of size 154, which is longer than the specified 0
# Created a chunk of size 228, which is longer than the specified 0
# Created a chunk of size 140, which is longer than the specified 0
# Created a chunk of size 153, which is longer than the specified 0
# Created a chunk of size 104, which is longer than the specified 0
# Created a chunk of size 161, which is longer than the specified 0
# Created a chunk of size 154, which is longer than the specified 0
# Created a chunk of size 155, which is longer than the specified 0
# Created a chunk of size 128, which is longer than the specified 0
# Created a chunk of size 187, which is longer than the specified 0
# Created a chunk of size 171, which is longer than the specified 0
# Created a chunk of size 155, which is longer than the specified 0
# Created a chunk of size 64, which is longer than the specified 0
# Created a chunk of size 171, which is longer than the specified 0
# Created a chunk of size 124, which is longer than the specified 0
# Created a chunk of size 74, which is longer than the specified 0
# Created a chunk of size 66, which is longer than the specified 0
# Created a chunk of size 144, which is longer than the specified 0
# Created a chunk of size 141, which is longer than the specified 0
# Created a chunk of size 129, which is longer than the specified 0
# Created a chunk of size 234, which is longer than the specified 0
# Created a chunk of size 152, which is longer than the specified 0
# Created a chunk of size 171, which is longer than the specified 0
# Created a chunk of size 155, which is longer than the specified 0
# Created a chunk of size 133, which is longer than the specified 0
# Created a chunk of size 119, which is longer than the specified 0
# Created a chunk of size 272, which is longer than the specified 0
# Created a chunk of size 246, which is longer than the specified 0
# Created a chunk of size 73, which is longer than the specified 0
# Created a chunk of size 112, which is longer than the specified 0
# Created a chunk of size 171, which is longer than the specified 0
# Created a chunk of size 180, which is longer than the specified 0
# Created a chunk of size 144, which is longer than the specified 0
# Created a chunk of size 119, which is longer than the specified 0
# Created a chunk of size 155, which is longer than the specified 0
# Created a chunk of size 129, which is longer than the specified 0
# Created a chunk of size 146, which is longer than the specified 0
# Created a chunk of size 162, which is longer than the specified 0
# Created a chunk of size 99, which is longer than the specified 0
# Created a chunk of size 207, which is longer than the specified 0
# Created a chunk of size 178, which is longer than the specified 0
# Created a chunk of size 239, which is longer than the specified 0
# Created a chunk of size 137, which is longer than the specified 0
# Created a chunk of size 162, which is longer than the specified 0
# Created a chunk of size 207, which is longer than the specified 0
# Created a chunk of size 242, which is longer than the specified 0
# Created a chunk of size 164, which is longer than the specified 0
# Created a chunk of size 71, which is longer than the specified 0
# Created a chunk of size 137, which is longer than the specified 0
# Created a chunk of size 133, which is longer than the specified 0
# Created a chunk of size 165, which is longer than the specified 0
# Created a chunk of size 167, which is longer than the specified 0
# Created a chunk of size 83, which is longer than the specified 0
# Created a chunk of size 171, which is longer than the specified 0
# Created a chunk of size 111, which is longer than the specified 0
# Created a chunk of size 114, which is longer than the specified 0
# Created a chunk of size 163, which is longer than the specified 0
# Created a chunk of size 112, which is longer than the specified 0
# Created a chunk of size 146, which is longer than the specified 0
# Created a chunk of size 165, which is longer than the specified 0
# Created a chunk of size 163, which is longer than the specified 0
# Created a chunk of size 100, which is longer than the specified 0
# Created a chunk of size 226, which is longer than the specified 0
# Created a chunk of size 150, which is longer than the specified 0
# Created a chunk of size 168, which is longer than the specified 0
# Created a chunk of size 108, which is longer than the specified 0
# Created a chunk of size 132, which is longer than the specified 0
# Created a chunk of size 132, which is longer than the specified 0
# Created a chunk of size 240, which is longer than the specified 0
# Created a chunk of size 154, which is longer than the specified 0
# Created a chunk of size 181, which is longer than the specified 0
# Created a chunk of size 89, which is longer than the specified 0
# Created a chunk of size 127, which is longer than the specified 0
# Created a chunk of size 204, which is longer than the specified 0
# Created a chunk of size 192, which is longer than the specified 0
# Created a chunk of size 96, which is longer than the specified 0
# Created a chunk of size 171, which is longer than the specified 0
# Created a chunk of size 117, which is longer than the specified 0
# Created a chunk of size 116, which is longer than the specified 0
# Created a chunk of size 94, which is longer than the specified 0
# Created a chunk of size 176, which is longer than the specified 0
# Created a chunk of size 79, which is longer than the specified 0
# Created a chunk of size 182, which is longer than the specified 0
# Created a chunk of size 107, which is longer than the specified 0
# Created a chunk of size 93, which is longer than the specified 0
# Created a chunk of size 149, which is longer than the specified 0
# Created a chunk of size 199, which is longer than the specified 0
# Created a chunk of size 181, which is longer than the specified 0
# Created a chunk of size 104, which is longer than the specified 0
# Created a chunk of size 137, which is longer than the specified 0
# Created a chunk of size 84, which is longer than the specified 0
# Created a chunk of size 150, which is longer than the specified 0
# Created a chunk of size 123, which is longer than the specified 0
# Created a chunk of size 143, which is longer than the specified 0
# Created a chunk of size 123, which is longer than the specified 0
# Created a chunk of size 123, which is longer than the specified 0
# Created a chunk of size 159, which is longer than the specified 0
# Created a chunk of size 174, which is longer than the specified 0
# Created a chunk of size 142, which is longer than the specified 0
# Created a chunk of size 185, which is longer than the specified 0
# Created a chunk of size 202, which is longer than the specified 0
# Created a chunk of size 111, which is longer than the specified 0
# Created a chunk of size 230, which is longer than the specified 0
# Created a chunk of size 137, which is longer than the specified 0
# Created a chunk of size 238, which is longer than the specified 0
# Created a chunk of size 147, which is longer than the specified 0
# Created a chunk of size 173, which is longer than the specified 0
# Created a chunk of size 139, which is longer than the specified 0
# Created a chunk of size 83, which is longer than the specified 0
# Created a chunk of size 153, which is longer than the specified 0
# Created a chunk of size 238, which is longer than the specified 0
# Created a chunk of size 217, which is longer than the specified 0
# Created a chunk of size 157, which is longer than the specified 0
# Created a chunk of size 118, which is longer than the specified 0
# Created a chunk of size 136, which is longer than the specified 0
# Created a chunk of size 155, which is longer than the specified 0
# Created a chunk of size 158, which is longer than the specified 0
# Created a chunk of size 146, which is longer than the specified 0
# Created a chunk of size 233, which is longer than the specified 0
# Created a chunk of size 98, which is longer than the specified 0
# Created a chunk of size 167, which is longer than the specified 0
# Created a chunk of size 97, which is longer than the specified 0
# Created a chunk of size 175, which is longer than the specified 0
# Created a chunk of size 104, which is longer than the specified 0
# Created a chunk of size 202, which is longer than the specified 0
# Created a chunk of size 121, which is longer than the specified 0
# Created a chunk of size 70, which is longer than the specified 0
# Created a chunk of size 97, which is longer than the specified 0
# Created a chunk of size 90, which is longer than the specified 0
# Created a chunk of size 107, which is longer than the specified 0
# Created a chunk of size 173, which is longer than the specified 0
# Created a chunk of size 150, which is longer than the specified 0
# Created a chunk of size 98, which is longer than the specified 0
# Created a chunk of size 209, which is longer than the specified 0
# Created a chunk of size 166, which is longer than the specified 0
# Created a chunk of size 96, which is longer than the specified 0
# Created a chunk of size 160, which is longer than the specified 0
# Created a chunk of size 121, which is longer than the specified 0
# Created a chunk of size 119, which is longer than the specified 0
# Created a chunk of size 162, which is longer than the specified 0
# Created a chunk of size 108, which is longer than the specified 0
# Created a chunk of size 154, which is longer than the specified 0
# Created a chunk of size 141, which is longer than the specified 0
# Created a chunk of size 161, which is longer than the specified 0
# Created a chunk of size 137, which is longer than the specified 0
# Created a chunk of size 208, which is longer than the specified 0
# Created a chunk of size 88, which is longer than the specified 0
# Created a chunk of size 85, which is longer than the specified 0
# Created a chunk of size 137, which is longer than the specified 0
# Created a chunk of size 223, which is longer than the specified 0
# Created a chunk of size 149, which is longer than the specified 0
# Created a chunk of size 145, which is longer than the specified 0
# Created a chunk of size 220, which is longer than the specified 0
# Created a chunk of size 125, which is longer than the specified 0
# Created a chunk of size 112, which is longer than the specified 0
# Created a chunk of size 114, which is longer than the specified 0
# Created a chunk of size 232, which is longer than the specified 0
# Created a chunk of size 88, which is longer than the specified 0
# Created a chunk of size 160, which is longer than the specified 0
# Created a chunk of size 80, which is longer than the specified 0
# Created a chunk of size 108, which is longer than the specified 0
# Created a chunk of size 133, which is longer than the specified 0
# Created a chunk of size 168, which is longer than the specified 0
# Created a chunk of size 81, which is longer than the specified 0
# Created a chunk of size 120, which is longer than the specified 0
# Created a chunk of size 244, which is longer than the specified 0
# Created a chunk of size 140, which is longer than the specified 0
# Created a chunk of size 190, which is longer than the specified 0
# Created a chunk of size 188, which is longer than the specified 0
# Created a chunk of size 92, which is longer than the specified 0
# Created a chunk of size 135, which is longer than the specified 0
# Created a chunk of size 175, which is longer than the specified 0
# Created a chunk of size 142, which is longer than the specified 0
# Created a chunk of size 151, which is longer than the specified 0
# Created a chunk of size 77, which is longer than the specified 0
# Created a chunk of size 120, which is longer than the specified 0
# Created a chunk of size 117, which is longer than the specified 0
# Created a chunk of size 238, which is longer than the specified 0
# Created a chunk of size 98, which is longer than the specified 0
# Created a chunk of size 48, which is longer than the specified 0
# Created a chunk of size 261, which is longer than the specified 0
# Created a chunk of size 108, which is longer than the specified 0
# Created a chunk of size 175, which is longer than the specified 0
# Created a chunk of size 122, which is longer than the specified 0
# Created a chunk of size 110, which is longer than the specified 0
# Created a chunk of size 70, which is longer than the specified 0
# Created a chunk of size 81, which is longer than the specified 0
# Created a chunk of size 209, which is longer than the specified 0
# Created a chunk of size 172, which is longer than the specified 0
# Created a chunk of size 201, which is longer than the specified 0
# Created a chunk of size 165, which is longer than the specified 0
# Created a chunk of size 315, which is longer than the specified 0
# Created a chunk of size 205, which is longer than the specified 0
# Created a chunk of size 133, which is longer than the specified 0
# Created a chunk of size 181, which is longer than the specified 0
# Created a chunk of size 130, which is longer than the specified 0
# Created a chunk of size 136, which is longer than the specified 0
# Created a chunk of size 66, which is longer than the specified 0
# Created a chunk of size 216, which is longer than the specified 0
# Created a chunk of size 106, which is longer than the specified 0
# Created a chunk of size 234, which is longer than the specified 0
# Created a chunk of size 117, which is longer than the specified 0
# Created a chunk of size 93, which is longer than the specified 0
# Created a chunk of size 256, which is longer than the specified 0
# Created a chunk of size 141, which is longer than the specified 0
# Created a chunk of size 154, which is longer than the specified 0
# Created a chunk of size 127, which is longer than the specified 0
# Created a chunk of size 173, which is longer than the specified 0
# Created a chunk of size 164, which is longer than the specified 0
# Created a chunk of size 210, which is longer than the specified 0
# Created a chunk of size 203, which is longer than the specified 0
# Created a chunk of size 182, which is longer than the specified 0
# Created a chunk of size 135, which is longer than the specified 0
# Created a chunk of size 131, which is longer than the specified 0
# Created a chunk of size 219, which is longer than the specified 0
# Created a chunk of size 94, which is longer than the specified 0
# Created a chunk of size 217, which is longer than the specified 0
# Created a chunk of size 185, which is longer than the specified 0
# Created a chunk of size 179, which is longer than the specified 0
# Created a chunk of size 119, which is longer than the specified 0
# Created a chunk of size 150, which is longer than the specified 0
# Created a chunk of size 218, which is longer than the specified 0
# Created a chunk of size 183, which is longer than the specified 0
# Created a chunk of size 107, which is longer than the specified 0
# Created a chunk of size 129, which is longer than the specified 0
# Created a chunk of size 161, which is longer than the specified 0
# Created a chunk of size 140, which is longer than the specified 0
# Created a chunk of size 144, which is longer than the specified 0
# Created a chunk of size 141, which is longer than the specified 0
# Created a chunk of size 221, which is longer than the specified 0
# Created a chunk of size 169, which is longer than the specified 0
# Created a chunk of size 182, which is longer than the specified 0
# Created a chunk of size 84, which is longer than the specified 0
# Created a chunk of size 159, which is longer than the specified 0
# Created a chunk of size 119, which is longer than the specified 0
# Created a chunk of size 134, which is longer than the specified 0
# Created a chunk of size 92, which is longer than the specified 0
# Created a chunk of size 125, which is longer than the specified 0
# Created a chunk of size 183, which is longer than the specified 0
# Created a chunk of size 153, which is longer than the specified 0
# Created a chunk of size 98, which is longer than the specified 0
# Created a chunk of size 148, which is longer than the specified 0
# Created a chunk of size 111, which is longer than the specified 0
# Created a chunk of size 83, which is longer than the specified 0
# Created a chunk of size 140, which is longer than the specified 0
# Created a chunk of size 157, which is longer than the specified 0
# Created a chunk of size 125, which is longer than the specified 0
# Created a chunk of size 94, which is longer than the specified 0
# Created a chunk of size 80, which is longer than the specified 0
# Created a chunk of size 234, which is longer than the specified 0
# Created a chunk of size 108, which is longer than the specified 0
# Created a chunk of size 197, which is longer than the specified 0
# Created a chunk of size 168, which is longer than the specified 0
# Created a chunk of size 133, which is longer than the specified 0
# Created a chunk of size 152, which is longer than the specified 0
# Created a chunk of size 91, which is longer than the specified 0
# Created a chunk of size 151, which is longer than the specified 0
# Created a chunk of size 101, which is longer than the specified 0
# Created a chunk of size 175, which is longer than the specified 0
# Created a chunk of size 148, which is longer than the specified 0
# Created a chunk of size 223, which is longer than the specified 0
# Created a chunk of size 170, which is longer than the specified 0
# Created a chunk of size 98, which is longer than the specified 0
# Created a chunk of size 192, which is longer than the specified 0
# Created a chunk of size 127, which is longer than the specified 0
# Created a chunk of size 92, which is longer than the specified 0
# Created a chunk of size 213, which is longer than the specified 0
# Created a chunk of size 152, which is longer than the specified 0
# Created a chunk of size 225, which is longer than the specified 0
# Created a chunk of size 147, which is longer than the specified 0
# Created a chunk of size 261, which is longer than the specified 0
# Created a chunk of size 181, which is longer than the specified 0
# Created a chunk of size 139, which is longer than the specified 0
# Created a chunk of size 156, which is longer than the specified 0
# Created a chunk of size 94, which is longer than the specified 0
# Created a chunk of size 200, which is longer than the specified 0
# Created a chunk of size 121, which is longer than the specified 0
# Created a chunk of size 102, which is longer than the specified 0
# Created a chunk of size 154, which is longer than the specified 0
# Created a chunk of size 163, which is longer than the specified 0
# Created a chunk of size 228, which is longer than the specified 0
# Created a chunk of size 130, which is longer than the specified 0
# Created a chunk of size 211, which is longer than the specified 0
# Created a chunk of size 244, which is longer than the specified 0
# Created a chunk of size 216, which is longer than the specified 0
# Created a chunk of size 135, which is longer than the specified 0
# Created a chunk of size 176, which is longer than the specified 0
# Created a chunk of size 233, which is longer than the specified 0
# Created a chunk of size 171, which is longer than the specified 0
# Created a chunk of size 107, which is longer than the specified 0
# Created a chunk of size 149, which is longer than the specified 0
# Created a chunk of size 110, which is longer than the specified 0
# Created a chunk of size 114, which is longer than the specified 0
# Created a chunk of size 208, which is longer than the specified 0
# Created a chunk of size 143, which is longer than the specified 0
# Created a chunk of size 168, which is longer than the specified 0
# Created a chunk of size 95, which is longer than the specified 0
# Created a chunk of size 149, which is longer than the specified 0
# Created a chunk of size 193, which is longer than the specified 0
# Created a chunk of size 142, which is longer than the specified 0
# Created a chunk of size 193, which is longer than the specified 0
# Created a chunk of size 97, which is longer than the specified 0
# Created a chunk of size 138, which is longer than the specified 0
# Created a chunk of size 196, which is longer than the specified 0
# Created a chunk of size 161, which is longer than the specified 0
# Created a chunk of size 125, which is longer than the specified 0
# Created a chunk of size 154, which is longer than the specified 0
# Created a chunk of size 151, which is longer than the specified 0
# Created a chunk of size 174, which is longer than the specified 0
# Created a chunk of size 155, which is longer than the specified 0
# Created a chunk of size 232, which is longer than the specified 0
# Created a chunk of size 160, which is longer than the specified 0
# Created a chunk of size 181, which is longer than the specified 0
# Created a chunk of size 93, which is longer than the specified 0
# Created a chunk of size 172, which is longer than the specified 0
# Created a chunk of size 140, which is longer than the specified 0
# Created a chunk of size 148, which is longer than the specified 0
# Created a chunk of size 163, which is longer than the specified 0
# Created a chunk of size 223, which is longer than the specified 0
# Created a chunk of size 127, which is longer than the specified 0
# Created a chunk of size 130, which is longer than the specified 0
# Created a chunk of size 86, which is longer than the specified 0
# Created a chunk of size 91, which is longer than the specified 0
# Created a chunk of size 138, which is longer than the specified 0
# Created a chunk of size 101, which is longer than the specified 0
# Created a chunk of size 223, which is longer than the specified 0
# Created a chunk of size 185, which is longer than the specified 0
# Created a chunk of size 147, which is longer than the specified 0
# Created a chunk of size 116, which is longer than the specified 0
# Created a chunk of size 233, which is longer than the specified 0
# Created a chunk of size 206, which is longer than the specified 0
# Created a chunk of size 170, which is longer than the specified 0
# Created a chunk of size 116, which is longer than the specified 0
# Created a chunk of size 239, which is longer than the specified 0
# Created a chunk of size 213, which is longer than the specified 0
# Created a chunk of size 170, which is longer than the specified 0
# Created a chunk of size 121, which is longer than the specified 0
# Created a chunk of size 115, which is longer than the specified 0
# Created a chunk of size 140, which is longer than the specified 0
# Created a chunk of size 170, which is longer than the specified 0
# Created a chunk of size 156, which is longer than the specified 0
# Created a chunk of size 113, which is longer than the specified 0
# Created a chunk of size 111, which is longer than the specified 0
# Created a chunk of size 133, which is longer than the specified 0
# Created a chunk of size 148, which is longer than the specified 0
# Created a chunk of size 162, which is longer than the specified 0
# Created a chunk of size 125, which is longer than the specified 0
# Created a chunk of size 152, which is longer than the specified 0
# Created a chunk of size 124, which is longer than the specified 0
# Created a chunk of size 186, which is longer than the specified 0
# Created a chunk of size 150, which is longer than the specified 0
# Created a chunk of size 126, which is longer than the specified 0
# Created a chunk of size 174, which is longer than the specified 0
# Created a chunk of size 143, which is longer than the specified 0
# Created a chunk of size 146, which is longer than the specified 0
# Created a chunk of size 164, which is longer than the specified 0
# Created a chunk of size 192, which is longer than the specified 0
# Created a chunk of size 168, which is longer than the specified 0
# Created a chunk of size 95, which is longer than the specified 0
# Created a chunk of size 112, which is longer than the specified 0
# Created a chunk of size 104, which is longer than the specified 0
# Created a chunk of size 132, which is longer than the specified 0
# Created a chunk of size 177, which is longer than the specified 0
# Created a chunk of size 165, which is longer than the specified 0
# Created a chunk of size 188, which is longer than the specified 0
# Created a chunk of size 147, which is longer than the specified 0
# Created a chunk of size 168, which is longer than the specified 0
# Created a chunk of size 155, which is longer than the specified 0
# Created a chunk of size 135, which is longer than the specified 0
# Created a chunk of size 147, which is longer than the specified 0
# Created a chunk of size 137, which is longer than the specified 0
# Created a chunk of size 120, which is longer than the specified 0
# Created a chunk of size 151, which is longer than the specified 0
# Created a chunk of size 114, which is longer than the specified 0
# Created a chunk of size 110, which is longer than the specified 0
# Created a chunk of size 148, which is longer than the specified 0
# Created a chunk of size 125, which is longer than the specified 0
# Created a chunk of size 123, which is longer than the specified 0
# Created a chunk of size 166, which is longer than the specified 0
# Created a chunk of size 89, which is longer than the specified 0
# Created a chunk of size 116, which is longer than the specified 0
# Created a chunk of size 195, which is longer than the specified 0
# Created a chunk of size 108, which is longer than the specified 0
# Created a chunk of size 221, which is longer than the specified 0
# Created a chunk of size 141, which is longer than the specified 0
# Created a chunk of size 139, which is longer than the specified 0
# Created a chunk of size 149, which is longer than the specified 0
# Created a chunk of size 139, which is longer than the specified 0
# Created a chunk of size 109, which is longer than the specified 0
# Created a chunk of size 108, which is longer than the specified 0
# Created a chunk of size 143, which is longer than the specified 0
# Created a chunk of size 132, which is longer than the specified 0
# Created a chunk of size 147, which is longer than the specified 0
# Created a chunk of size 118, which is longer than the specified 0
# Created a chunk of size 139, which is longer than the specified 0
# Created a chunk of size 108, which is longer than the specified 0
# Created a chunk of size 180, which is longer than the specified 0
# Created a chunk of size 138, which is longer than the specified 0
# Created a chunk of size 140, which is longer than the specified 0
# Created a chunk of size 94, which is longer than the specified 0
# Created a chunk of size 77, which is longer than the specified 0
# Created a chunk of size 96, which is longer than the specified 0
# Created a chunk of size 221, which is longer than the specified 0
# Created a chunk of size 189, which is longer than the specified 0
# Created a chunk of size 148, which is longer than the specified 0
# Created a chunk of size 179, which is longer than the specified 0
# Created a chunk of size 178, which is longer than the specified 0
# Created a chunk of size 157, which is longer than the specified 0
# Created a chunk of size 137, which is longer than the specified 0
# Created a chunk of size 171, which is longer than the specified 0
# Created a chunk of size 148, which is longer than the specified 0
# Created a chunk of size 151, which is longer than the specified 0
# Created a chunk of size 137, which is longer than the specified 0
# Created a chunk of size 112, which is longer than the specified 0
# Created a chunk of size 89, which is longer than the specified 0
# Created a chunk of size 243, which is longer than the specified 0
# Created a chunk of size 208, which is longer than the specified 0
# Created a chunk of size 121, which is longer than the specified 0
# Created a chunk of size 179, which is longer than the specified 0
# Created a chunk of size 111, which is longer than the specified 0
# Created a chunk of size 231, which is longer than the specified 0
# Created a chunk of size 232, which is longer than the specified 0
# ...
# Created a chunk of size 147, which is longer than the specified 0
# Created a chunk of size 160, which is longer than the specified 0
# Created a chunk of size 171, which is longer than the specified 0
# Created a chunk of size 91, which is longer than the specified 0
# Created a chunk of size 226, which is longer than the specified 0
# Created a chunk of size 176, which is longer than the specified 0
# Created a chunk of size 142, which is longer than the specified 0
# Created a chunk of size 176, which is longer than the specified 0
# Created a chunk of size 120, which is longer than the specified 0
# Created a chunk of size 124, which is longer than the specified 0
# Created a chunk of size 221, which is longer than the specified 0
# Created a chunk of size 240, which is longer than the specified 0
# Created a chunk of size 178, which is longer than the specified 0
# Created a chunk of size 161, which is longer than the specified 0
# Created a chunk of size 206, which is longer than the specified 0
# Created a chunk of size 145, which is longer than the specified 0
# Created a chunk of size 108, which is longer than the specified 0
# Created a chunk of size 175, which is longer than the specified 0
# Created a chunk of size 113, which is longer than the specified 0
# Created a chunk of size 191, which is longer than the specified 0
# Created a chunk of size 135, which is longer than the specified 0
# Created a chunk of size 83, which is longer than the specified 0
# Created a chunk of size 227, which is longer than the specified 0
# Created a chunk of size 103, which is longer than the specified 0
# Created a chunk of size 144, which is longer than the specified 0
# Created a chunk of size 145, which is longer than the specified 0
# Created a chunk of size 147, which is longer than the specified 0
# Created a chunk of size 117, which is longer than the specified 0
# Created a chunk of size 141, which is longer than the specified 0
# Created a chunk of size 192, which is longer than the specified 0
# Created a chunk of size 127, which is longer than the specified 0
# Created a chunk of size 157, which is longer than the specified 0
# Created a chunk of size 127, which is longer than the specified 0
# Created a chunk of size 185, which is longer than the specified 0
# Created a chunk of size 146, which is longer than the specified 0
# Created a chunk of size 225, which is longer than the specified 0
# Created a chunk of size 112, which is longer than the specified 0
# Created a chunk of size 169, which is longer than the specified 0
# Created a chunk of size 91, which is longer than the specified 0
# Created a chunk of size 95, which is longer than the specified 0
# Created a chunk of size 129, which is longer than the specified 0
# Created a chunk of size 230, which is longer than the specified 0
# Created a chunk of size 128, which is longer than the specified 0
# Created a chunk of size 88, which is longer than the specified 0
# Created a chunk of size 204, which is longer than the specified 0
# Created a chunk of size 128, which is longer than the specified 0
# Created a chunk of size 89, which is longer than the specified 0
# Created a chunk of size 157, which is longer than the specified 0
# Created a chunk of size 99, which is longer than the specified 0
# Created a chunk of size 145, which is longer than the specified 0
# Created a chunk of size 157, which is longer than the specified 0
# Created a chunk of size 134, which is longer than the specified 0
# Created a chunk of size 138, which is longer than the specified 0
# Created a chunk of size 152, which is longer than the specified 0
# Created a chunk of size 95, which is longer than the specified 0
# Created a chunk of size 149, which is longer than the specified 0
# Created a chunk of size 114, which is longer than the specified 0
# Created a chunk of size 132, which is longer than the specified 0
# Created a chunk of size 139, which is longer than the specified 0
# Created a chunk of size 147, which is longer than the specified 0
# Created a chunk of size 67, which is longer than the specified 0
# Created a chunk of size 174, which is longer than the specified 0
# Created a chunk of size 122, which is longer than the specified 0
# Created a chunk of size 193, which is longer than the specified 0
# Created a chunk of size 104, which is longer than the specified 0
# Created a chunk of size 94, which is longer than the specified 0
# Created a chunk of size 81, which is longer than the specified 0
# Created a chunk of size 123, which is longer than the specified 0
# Created a chunk of size 153, which is longer than the specified 0
# Created a chunk of size 129, which is longer than the specified 0
# Created a chunk of size 142, which is longer than the specified 0
# Created a chunk of size 112, which is longer than the specified 0
# Created a chunk of size 209, which is longer than the specified 0
# Created a chunk of size 118, which is longer than the specified 0
# Created a chunk of size 44, which is longer than the specified 0
# Created a chunk of size 91, which is longer than the specified 0
# Created a chunk of size 106, which is longer than the specified 0
# Created a chunk of size 215, which is longer than the specified 0
# Created a chunk of size 90, which is longer than the specified 0
# Created a chunk of size 144, which is longer than the specified 0
# Created a chunk of size 113, which is longer than the specified 0
# Created a chunk of size 135, which is longer than the specified 0
# Created a chunk of size 176, which is longer than the specified 0
# Created a chunk of size 155, which is longer than the specified 0
# Created a chunk of size 180, which is longer than the specified 0
# Created a chunk of size 91, which is longer than the specified 0
# Created a chunk of size 213, which is longer than the specified 0
# Created a chunk of size 184, which is longer than the specified 0
# Created a chunk of size 111, which is longer than the specified 0
# Created a chunk of size 106, which is longer than the specified 0
# Created a chunk of size 130, which is longer than the specified 0
# Created a chunk of size 135, which is longer than the specified 0
# Created a chunk of size 143, which is longer than the specified 0
# Created a chunk of size 110, which is longer than the specified 0
# Created a chunk of size 216, which is longer than the specified 0
# Created a chunk of size 106, which is longer than the specified 0
# Created a chunk of size 211, which is longer than the specified 0
# Created a chunk of size 172, which is longer than the specified 0
# Created a chunk of size 123, which is longer than the specified 0
# Created a chunk of size 170, which is longer than the specified 0
# Created a chunk of size 85, which is longer than the specified 0
# Created a chunk of size 147, which is longer than the specified 0
# Created a chunk of size 135, which is longer than the specified 0
# Created a chunk of size 79, which is longer than the specified 0
# Created a chunk of size 121, which is longer than the specified 0
# Created a chunk of size 201, which is longer than the specified 0
# Created a chunk of size 69, which is longer than the specified 0
# Created a chunk of size 94, which is longer than the specified 0
# Created a chunk of size 102, which is longer than the specified 0
# Created a chunk of size 115, which is longer than the specified 0
# Created a chunk of size 118, which is longer than the specified 0
# Created a chunk of size 97, which is longer than the specified 0
# Created a chunk of size 157, which is longer than the specified 0
# Created a chunk of size 146, which is longer than the specified 0
# Created a chunk of size 160, which is longer than the specified 0
# Created a chunk of size 125, which is longer than the specified 0
# Created a chunk of size 137, which is longer than the specified 0
# Created a chunk of size 118, which is longer than the specified 0
# Created a chunk of size 87, which is longer than the specified 0
# Created a chunk of size 98, which is longer than the specified 0
# Created a chunk of size 138, which is longer than the specified 0
# Created a chunk of size 98, which is longer than the specified 0
# Created a chunk of size 150, which is longer than the specified 0
# Created a chunk of size 125, which is longer than the specified 0
# Created a chunk of size 238, which is longer than the specified 0
# Created a chunk of size 118, which is longer than the specified 0
# Created a chunk of size 109, which is longer than the specified 0
# Created a chunk of size 88, which is longer than the specified 0
# Created a chunk of size 184, which is longer than the specified 0
# Created a chunk of size 167, which is longer than the specified 0
# Created a chunk of size 183, which is longer than the specified 0
# Created a chunk of size 130, which is longer than the specified 0
# Created a chunk of size 155, which is longer than the specified 0
# Created a chunk of size 229, which is longer than the specified 0
# Created a chunk of size 200, which is longer than the specified 0
# Created a chunk of size 174, which is longer than the specified 0
# Created a chunk of size 157, which is longer than the specified 0
# Created a chunk of size 162, which is longer than the specified 0
# Created a chunk of size 235, which is longer than the specified 0
# Created a chunk of size 132, which is longer than the specified 0
# Created a chunk of size 193, which is longer than the specified 0
# Created a chunk of size 158, which is longer than the specified 0
# Created a chunk of size 93, which is longer than the specified 0
# Created a chunk of size 110, which is longer than the specified 0
# Created a chunk of size 199, which is longer than the specified 0
# Created a chunk of size 223, which is longer than the specified 0
# Created a chunk of size 111, which is longer than the specified 0
# Created a chunk of size 101, which is longer than the specified 0
# Created a chunk of size 160, which is longer than the specified 0
# Created a chunk of size 150, which is longer than the specified 0
# Created a chunk of size 152, which is longer than the specified 0
# Created a chunk of size 185, which is longer than the specified 0
# Created a chunk of size 209, which is longer than the specified 0
# Created a chunk of size 174, which is longer than the specified 0
# Created a chunk of size 212, which is longer than the specified 0
# Created a chunk of size 220, which is longer than the specified 0
# Created a chunk of size 190, which is longer than the specified 0
# Created a chunk of size 155, which is longer than the specified 0
# Created a chunk of size 183, which is longer than the specified 0
# Created a chunk of size 121, which is longer than the specified 0
# Created a chunk of size 131, which is longer than the specified 0
# Created a chunk of size 144, which is longer than the specified 0
# Created a chunk of size 168, which is longer than the specified 0
# Created a chunk of size 209, which is longer than the specified 0
# Created a chunk of size 164, which is longer than the specified 0
# Created a chunk of size 143, which is longer than the specified 0
# Created a chunk of size 219, which is longer than the specified 0
# Created a chunk of size 130, which is longer than the specified 0
# Created a chunk of size 125, which is longer than the specified 0
# Created a chunk of size 134, which is longer than the specified 0
# Created a chunk of size 192, which is longer than the specified 0
# Created a chunk of size 96, which is longer than the specified 0
# Created a chunk of size 143, which is longer than the specified 0
# Created a chunk of size 227, which is longer than the specified 0
# Created a chunk of size 97, which is longer than the specified 0
# Created a chunk of size 169, which is longer than the specified 0
# Created a chunk of size 169, which is longer than the specified 0
# Created a chunk of size 132, which is longer than the specified 0
# Created a chunk of size 317, which is longer than the specified 0
# Created a chunk of size 146, which is longer than the specified 0
# Created a chunk of size 194, which is longer than the specified 0
# Created a chunk of size 112, which is longer than the specified 0
# Created a chunk of size 156, which is longer than the specified 0
# Created a chunk of size 97, which is longer than the specified 0
# Created a chunk of size 158, which is longer than the specified 0
# Created a chunk of size 201, which is longer than the specified 0
# Created a chunk of size 123, which is longer than the specified 0
# Created a chunk of size 167, which is longer than the specified 0
# Created a chunk of size 111, which is longer than the specified 0
# Created a chunk of size 153, which is longer than the specified 0
# Created a chunk of size 157, which is longer than the specified 0
# Created a chunk of size 135, which is longer than the specified 0
# Created a chunk of size 165, which is longer than the specified 0
# Created a chunk of size 95, which is longer than the specified 0
# Created a chunk of size 169, which is longer than the specified 0
# Created a chunk of size 143, which is longer than the specified 0
# Created a chunk of size 203, which is longer than the specified 0
# Created a chunk of size 93, which is longer than the specified 0
# Created a chunk of size 128, which is longer than the specified 0
# Created a chunk of size 149, which is longer than the specified 0
# Created a chunk of size 112, which is longer than the specified 0
# Created a chunk of size 174, which is longer than the specified 0
# Created a chunk of size 150, which is longer than the specified 0
# Created a chunk of size 222, which is longer than the specified 0
# Created a chunk of size 117, which is longer than the specified 0
# Created a chunk of size 159, which is longer than the specified 0
# Created a chunk of size 150, which is longer than the specified 0
# Created a chunk of size 179, which is longer than the specified 0
# Created a chunk of size 112, which is longer than the specified 0
# Created a chunk of size 186, which is longer than the specified 0
# Created a chunk of size 79, which is longer than the specified 0
# Created a chunk of size 133, which is longer than the specified 0
# Created a chunk of size 97, which is longer than the specified 0
# Created a chunk of size 176, which is longer than the specified 0
# Created a chunk of size 116, which is longer than the specified 0
# Created a chunk of size 146, which is longer than the specified 0
# Created a chunk of size 162, which is longer than the specified 0
# Created a chunk of size 132, which is longer than the specified 0
# Created a chunk of size 124, which is longer than the specified 0
# Created a chunk of size 102, which is longer than the specified 0
# Created a chunk of size 101, which is longer than the specified 0
# Created a chunk of size 131, which is longer than the specified 0
# Created a chunk of size 129, which is longer than the specified 0
# Created a chunk of size 226, which is longer than the specified 0
# Created a chunk of size 233, which is longer than the specified 0
# Created a chunk of size 142, which is longer than the specified 0
# Created a chunk of size 242, which is longer than the specified 0
# Created a chunk of size 127, which is longer than the specified 0
# Created a chunk of size 225, which is longer than the specified 0
# Created a chunk of size 169, which is longer than the specified 0
# Created a chunk of size 109, which is longer than the specified 0
# Created a chunk of size 135, which is longer than the specified 0
# Created a chunk of size 122, which is longer than the specified 0
# Created a chunk of size 127, which is longer than the specified 0
# Created a chunk of size 109, which is longer than the specified 0
# Created a chunk of size 134, which is longer than the specified 0
# Created a chunk of size 101, which is longer than the specified 0
# Created a chunk of size 205, which is longer than the specified 0
# Created a chunk of size 149, which is longer than the specified 0
# Created a chunk of size 93, which is longer than the specified 0
# Created a chunk of size 155, which is longer than the specified 0
# Created a chunk of size 168, which is longer than the specified 0

# %%
documents[0]
# Out:
# Document(metadata={'source': 'tagged_description.txt'}, page_content='1 Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.')

# %%
# Build Vector Search

embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2")
db_movies = Chroma.from_documents(documents, embedding=embedding_model)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
query = "A crime drama movie"
docs = db_movies.similarity_search(query, k=10)
docs
# Out:
# [Document(id='a3c7f30f-1282-4b8b-9ac0-c26a1743773b', metadata={'source': 'tagged_description.txt'}, page_content='815 This Hong Kong-set crime drama follows the lives of a hitman, hoping to get out of the business, and his elusive female partner.'),
#  Document(id='efccaaab-0ca8-405c-97af-ba286b44a3db', metadata={'source': 'tagged_description.txt'}, page_content='521 In Detroit, a lonely pop culture geek marries a call girl, steals cocaine from her pimp, and tries to sell it in Hollywood. Meanwhile, the owners of the cocaine, the Mob, track them down in an attempt to reclaim it.'),
#  Document(id='dbe706c3-7031-42e6-8446-311bc7e26572', metadata={'source': 'tagged_description.txt'}, page_content='603 A secret agent exacts revenge on a serial killer through a series of captures and releases.'),
#  Document(id='cc4c887d-4ed2-41e5-a9ef-60e61f77a396', metadata={'source': 'tagged_description.txt'}, page_content='92 A story of love between a mentally-ill father who was wrongly accused of murder and his lovely six years old daughter. The prison would be their home. Based on the 2013 Korean movie 7-beon-bang-ui seon-mul (2013).'),
#  Document(id='7ed72e79-9b0b-4dc3-a38b-6f5fa9dc8e81', metadata={'source': 'tagged_description.txt'}, page_content='907 When a criminal mastermind uses a trio of orphan girls as pawns for a grand scheme, he finds their love is profoundly changing him for the better.'),
#  Document(id='4699d833-b502-4ede-8904-76c524128077', metadata={'source': 'tagged_description.txt'}, page_content='457 A private detective takes on a case that involves him with three eccentric criminals, a gorgeous liar, and their quest for a priceless statuette.'),
#  Document(id='94712fc0-d962-4776-9386-4fe36191b777', metadata={'source': 'tagged_description.txt'}, page_content='902 Shot documentary-style, this film follows the daily grind of two young police officers in LA who are partners and friends, and what happens when they meet criminal forces greater than themselves.'),
#  Document(id='eaa533ac-604a-4e66-abec-16970cd57bde', metadata={'source': 'tagged_description.txt'}, page_content='901 A S.W.A.T. team becomes trapped in a tenement run by a ruthless mobster and his army of killers and thugs.'),
#  Document(id='9ae4238b-50ff-43a9-bd1e-70a994135ba1', metadata={'source': 'tagged_description.txt'}, page_content='1000 A man in London tries to help a counter-espionage Agent. But when the Agent is killed, and the man stands accused, he must go on the run to save himself and stop a spy ring which is trying to steal top secret information.'),
#  Document(id='31ee54af-ff68-4603-9405-3921ca68e0db', metadata={'source': 'tagged_description.txt'}, page_content="905 A stubborn teenager enlists the help of a tough U.S. Marshal to track down her father's murderer.")]

# %%
movies[movies["Unique_id"] == int(docs[0].page_content.split()[0].strip())]
# Out:
#                                            Poster_Link   Series_Title  \
# 814  https://m.media-amazon.com/images/M/MV5BZjM4NW...  Do lok tin si
#
#     Released_Year Runtime                 Genre  IMDB_Rating  \
# 814          1995  99 min  Comedy, Crime, Drama          7.7
#
#                                               Overview      Director  \
# 814  This Hong Kong-set crime drama follows the liv...  Kar-Wai Wong
#
#         Star1          Star2              Star3          Star4  No_of_Votes  \
# 814  Leon Lai  Michelle Reis  Takeshi Kaneshiro  Charlie Yeung        26429
#
#      Unique_id                                 tagged_description  \
# 814        815  815 This Hong Kong-set crime drama follows the...
#
#                                     Tagged_description
# 814  815 This Hong Kong-set crime drama follows the...

# %%
def retrieve_sementic_recommendations(
    query: str,
    top_k: int = 10,
) -> pd.DataFrame:
    recs = db_movies.similarity_search(query, k=50)
    
    movies_list = []
    
    for i in range(0, len(recs)):
        movies_list += [int(recs[i].page_content.strip('"').split()[0])]
        
    return movies[movies["Unique_id"].isin(movies_list)].head(top_k)

# %%
retrieve_sementic_recommendations("A movie about crime drama")
# Out:
#                                            Poster_Link  \
# 17   https://m.media-amazon.com/images/M/MV5BZjA0OW...
# 73   https://m.media-amazon.com/images/M/MV5BZWFlYm...
# 87   https://m.media-amazon.com/images/M/MV5BYmY3Mz...
# 91   https://m.media-amazon.com/images/M/MV5BOGE3N2...
# 119  https://m.media-amazon.com/images/M/MV5BYTE4OD...
# 136  https://m.media-amazon.com/images/M/MV5BYmJhZm...
# 162  https://m.media-amazon.com/images/M/MV5BMDQ2Yz...
# 177  https://m.media-amazon.com/images/M/MV5BOGZiM2...
# 261  https://m.media-amazon.com/images/M/MV5BMGQ5Mz...
# 283  https://m.media-amazon.com/images/M/MV5BOGMwYm...
#
#                         Series_Title Released_Year  Runtime  \
# 17   One Flew Over the Cuckoo's Nest          1975  133 min
# 73                       The Shining          1980  146 min
# 87                          Drishyam          2013  160 min
# 91              Miracle in cell NO.7          2019  132 min
# 119                          Vertigo          1958  128 min
# 136                         Drishyam          2015  163 min
# 162                L.A. Confidential          1997  138 min
# 177                           Sholay          1975  204 min
# 261               Chung Hing sam lam          1994  102 min
# 283                        Chinatown          1974  130 min
#
#                           Genre  IMDB_Rating  \
# 17                        Drama          8.7
# 73                Drama, Horror          8.4
# 87       Crime, Drama, Thriller          8.3
# 91                        Drama          8.3
# 119  Mystery, Romance, Thriller          8.3
# 136       Crime, Drama, Mystery          8.2
# 162       Crime, Drama, Mystery          8.2
# 177   Action, Adventure, Comedy          8.2
# 261        Comedy, Crime, Drama          8.1
# 283    Drama, Mystery, Thriller          8.1
#
#                                               Overview            Director  \
# 17   A criminal pleads insanity and is admitted to ...        Milos Forman
# 73   A family heads to an isolated hotel for the wi...     Stanley Kubrick
# 87   A man goes to extreme lengths to save his fami...       Jeethu Joseph
# 91   A story of love between a mentally-ill father ...  Mehmet Ada Öztekin
# 119  A former police detective juggles wrestling wi...    Alfred Hitchcock
# 136  Desperate measures are taken by a man who trie...     Nishikant Kamat
# 162  As corruption grows in 1950s Los Angeles, thre...       Curtis Hanson
# 177  After his family is murdered by a notorious an...        Ramesh Sippy
# 261  Two melancholy Hong Kong policemen fall in lov...        Kar-Wai Wong
# 283  A private detective hired to expose an adulter...      Roman Polanski
#
#                   Star1                 Star2                Star3  \
# 17       Jack Nicholson       Louise Fletcher     Michael Berryman
# 73       Jack Nicholson        Shelley Duvall          Danny Lloyd
# 87             Mohanlal                 Meena         Asha Sharath
# 91   Aras Bulut Iynemli  Nisa Sofiya Aksongur         Deniz Baysal
# 119       James Stewart             Kim Novak   Barbara Bel Geddes
# 136          Ajay Devgn          Shriya Saran                 Tabu
# 162        Kevin Spacey         Russell Crowe           Guy Pearce
# 177       Sanjeev Kumar            Dharmendra     Amitabh Bachchan
# 261        Brigitte Lin     Takeshi Kaneshiro  Tony Chiu-Wai Leung
# 283      Jack Nicholson          Faye Dunaway          John Huston
#
#                   Star4  No_of_Votes  Unique_id  \
# 17         Peter Brocco       918088         18
# 73     Scatman Crothers       898237         74
# 87               Ansiba        30722         88
# 91   Celile Toyon Uysal        33935         92
# 119         Tom Helmore       364368        120
# 136        Rajat Kapoor        70367        137
# 162        Kim Basinger       531967        163
# 177          Amjad Khan        51284        178
# 261           Faye Wong        63122        262
# 283         Perry Lopez       294230        284
#
#                                     tagged_description  \
# 17   18 A criminal pleads insanity and is admitted ...
# 73   74 A family heads to an isolated hotel for the...
# 87   88 A man goes to extreme lengths to save his f...
# 91   92 A story of love between a mentally-ill fath...
# 119  120 A former police detective juggles wrestlin...
# 136  137 Desperate measures are taken by a man who ...
# 162  163 As corruption grows in 1950s Los Angeles, ...
# 177  178 After his family is murdered by a notoriou...
# 261  262 Two melancholy Hong Kong policemen fall in...
# 283  284 A private detective hired to expose an adu...
#
#                                     Tagged_description
# 17   18 A criminal pleads insanity and is admitted ...
# 73   74 A family heads to an isolated hotel for the...
# 87   88 A man goes to extreme lengths to save his f...
# 91   92 A story of love between a mentally-ill fath...
# 119  120 A former police detective juggles wrestlin...
# 136  137 Desperate measures are taken by a man who ...
# 162  163 As corruption grows in 1950s Los Angeles, ...
# 177  178 After his family is murdered by a notoriou...
# 261  262 Two melancholy Hong Kong policemen fall in...
# 283  284 A private detective hired to expose an adu...
